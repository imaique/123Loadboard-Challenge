# %%
import pandas as pd

df = pd.read_csv('trucks.csv')
df
# Out:
#        seq   type            timestamp  truckId  positionLatitude  \
# 0      267  Truck  2023-11-17T10:26:25      341         36.761456
# 1      268  Truck  2023-11-17T10:27:05      120         40.023842
# 2      269  Truck  2023-11-17T10:27:10      120         40.031013
# 3      271  Truck  2023-11-17T10:27:24      206         40.271824
# 4      272  Truck  2023-11-17T10:27:32      326         35.336109
# ...    ...    ...                  ...      ...               ...
# 5827  2496  Truck  2023-11-17T22:58:03      238         42.132271
# 5828  2497  Truck  2023-11-17T22:59:24      353         42.473766
# 5829  2498  Truck  2023-11-17T22:59:27      290         39.569466
# 5830  2499  Truck  2023-11-17T22:59:35      241         38.293682
# 5831  2500  Truck  2023-11-17T22:59:56      237         37.807678
#
#       positionLongitude equipType nextTripLengthPreference
# 0            -81.826714   Flatbed                     Long
# ...

# %%
serie = df['truckId'].value_counts()
# Out:
# 366    57
# 292    42
# 331    41
# 110    40
# 106    40
#        ..
# 428     3
# 345     3
# 222     3
# 197     3
# 123     2
# Name: truckId, Length: 322, dtype: int64

# %%
df.loc[df['truckId'] == 123]
# Out:
#       seq   type            timestamp  truckId  positionLatitude  \
# 1978  233  Truck  2023-11-17T10:13:55      123         43.554779
# 3978  233  Truck  2023-11-17T10:13:55      123         43.554779
#
#       positionLongitude equipType nextTripLengthPreference
# 1978         -79.847824   Flatbed                     Long
# 3978         -79.847824   Flatbed                     Long
